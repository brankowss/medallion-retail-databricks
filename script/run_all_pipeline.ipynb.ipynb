# %% [markdown]
# # 1. Setup Environment

# %%
# %run ./init_lakehouse.ipynb

# %%
# %run ./helpers/bronze_engine.ipynb

# %%
# %run ./helpers/silver_engine.ipynb

# %% [markdown]
# # 2. Ingestion (Bronze)

# %%
# %run ./bronze/bronze_ingestion.ipynb

# %% [markdown]
# # 3. Transformation (Silver)

# %%
# %run ./silver/crm/silver_crm_cust_info.ipynb

# %%
# %run ./silver/crm/silver_crm_prd_info.ipynb

# %%
# %run ./silver/crm/silver_crm_sales_details.ipynb

# %%
# %run ./silver/erp/silver_erp_cust_az12.ipynb

# %%
# %run ./silver/erp/silver_erp_loc_a101.ipynb

# %%
# %run ./silver/erp/silver_erp_px_cat_g1v2.ipynb

# %% [markdown]
# # 4. Data Warehouse (Gold)

# %%
# %run ./gold/gold_dim_customers.ipynb

# %%
# %run ./gold/gold_dim_products.ipynb

# %%
# %run ./gold/gold_fact_sales.ipynb

# %% [markdown]
# # 5. Final Validation (8 Tests)

# %%
# %run ./tests/data_quality_tests.ipynb

# %% [markdown]
# # 6. Check status

# %%
display(spark.sql("SHOW TABLES IN workspace.gold"))
